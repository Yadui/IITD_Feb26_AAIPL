# %%
import json
import yaml
from agents.question_model import QAgent

# Load topics
with open("assets/topics.json") as f:
    topics = json.load(f)

# Load ICL samples
inc_samples = QuestioningAgent.load_icl_samples("assets/topics_example.json")

# Create agent
agent_base = QAgent(use_lora=False)

# Load generation config
with open("qgen.yaml") as f:
    gen_kwargs = yaml.safe_load(f)

# Generate 20 questions
questions, tls, gts = agent_base.generate_batches(
    num_questions=20,
    topics=topics,
    batch_size=5,
    wadvsys=True,
    wicl=True,
    inc_samples=inc_samples,
    **gen_kwargs
)

print("Generated:", len(questions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       7     topics = json.load(f)
#       9 # Load ICL samples
# ---> 10 inc_samples = QuestioningAgent.load_icl_samples("assets/topics_example.json")
#      12 # Create agent
#      13 agent_base = QAgent(use_lora=False)
#
# NameError: name 'QuestioningAgent' is not defined

# %%
filtered = agent.filter_questions(questions)

print("Total generated:", len(questions))
print("Valid questions:", len(filtered))
print("Validity rate:", len(filtered) / len(questions))
# Out:
# Total generated: 20
# Valid questions: 19
# Validity rate: 0.95

# %%
from agents.answer_agent import AnsweringAgent

a_agent = AnsweringAgent()

with open("agen.yaml") as f:
    agen_kwargs = yaml.safe_load(f)

answers, tls, gts = a_agent.answer_batches(
    questions=filtered,
    batch_size=5,
    **agen_kwargs
)

filtered_answers = a_agent.filter_answers(answers)

correct = 0
for q, a in zip(filtered, filtered_answers):
    if a is not None and q["answer"][0] == a["answer"]:
        correct += 1

accuracy = correct / len(filtered)
print("A-Agent Accuracy:", accuracy)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# STEPS: : 5batch [00:14,  2.89s/batch]
# A-Agent Accuracy: 0.2631578947368421

# %%
N = len(filtered)
num_correct = sum(
    1 for q, a in zip(filtered, filtered_answers)
    if a is not None and q["answer"][0] == a["answer"]
)

a_score = num_correct * 100 / (N + 1e-9)
q_score = (N - num_correct) * 100 / (N + 1e-9)

print("Number of questions:", N)
print("Correct answers:", num_correct)
print("A-Agent Score:", a_score)
print("Q-Agent Score:", q_score)
# Out:
# Number of questions: 19
# Correct answers: 5
# A-Agent Score: 26.31578947229917
# Q-Agent Score: 73.68421052243767

# %%
from agents.answer_agent import AnsweringAgent
a = AnsweringAgent()
print("Loaded successfully")
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Loaded successfully

# %%
from agents.question_agent import QuestioningAgent
import json

agent = QuestioningAgent()

with open("outputs/questions_50.json") as f:
    questions = json.load(f)

filtered = agent.filter_questions(questions)

print("Generated:", len(questions))
print("Valid:", len(filtered))
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Generated: 50
# Valid: 50

# %%
syll = [q for q in filtered if "Syllogism" in q["topic"]]
series = [q for q in filtered if "Series" in q["topic"]]
blood = [q for q in filtered if "Blood" in q["topic"]]

for q in series[:10]:
    print(q)

for q in syll[:10]:
    print(q)

for q in blood[:10]:
    print(q)
# Out:
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) IK14', 'C) IH14', 'D) IG14'], 'answer': 'B', 'explanation': "The sequence alternates between single-letter increments followed by double-letter increments while numbers increment sequentially starting at 8. Thus, after 'GH', it should continue with 'IJ' then 'IK'. Correct continuation is IK14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) IK14', 'C) II14', 'D) IH14'], 'answer': 'C', 'explanation': "The sequence alternates between single-letter groups increasing by one letter at every step and double-letter groups where both letters increment sequentially while numbers also rise consecutively starting from 8. Thus, after 'GH', comes 'II' followed by 14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) IK14', 'C) IH14', 'D) IG14'], 'answer': 'B', 'explanation': "The sequence alternates between single-letter increments followed by double-letter increments while numbers increment sequentially starting at 8. Thus, after 'GH', it should continue with 'IJ' then 'IK'. Correct continuation is IK14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) IK14', 'C) II14', 'D) IH14'], 'answer': 'C', 'explanation': "The sequence alternates between single-letter increments followed by double-letter increments while numbers increment sequentially starting at 8. Thus, after 'GH', comes 'II' making it II14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) II14', 'C) IH14', 'D) IG14'], 'answer': 'A', 'explanation': "The sequence alternates between single-letter groups increasing by one letter at every step and double-letter groups where both letters increment sequentially while numbers also rise consecutively starting from 8. Thus, after 'GH', comes 'IA'. Therefore, the final pair should read IA followed by 14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) IK14', 'C) IH14', 'D) IG14'], 'answer': 'B', 'explanation': "The sequence alternates between single-letter increments followed by double-letter increments while numbers increment sequentially starting at 8. Thus, after 'GH', it should continue with 'IJ' then 'IK'. Correct continuation is IK14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) IK14', 'C) II14', 'D) IH14'], 'answer': 'C', 'explanation': "The sequence alternates between single-letter groups increasing by one letter at every step and double-letter groups where both letters increment sequentially while numbers also rise consecutively starting from 8. Thus, after 'GH', comes 'II' followed by 14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) IK14', 'C) IH14', 'D) II14'], 'answer': 'B', 'explanation': "The sequence alternates between single-letter groups increasing by one letter at every step and double-letter groups where both letters increment sequentially while numbers also rise consecutively starting from 8. Thus, after 'GH', comes 'IJ' followed by 14 making it IK14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) II14', 'C) IH14', 'D) IG14'], 'answer': 'C', 'explanation': "The sequence alternates between single-letter increments followed by double-letter increments while numbers increment sequentially starting at 8. Thus, after 'GH', it should revert back to a single letter before continuing numerically up to 14 resulting in IH14."}
# {'topic': 'Series and Patterns/Mixed Series (Alphanumeric)', 'question': '_8_, _9_, AB10, CD11, EF12, GH13, __', 'choices': ['A) IA14', 'B) II14', 'C) IH14', 'D) IG14'], 'answer': 'A', 'explanation': "The sequence alternates between single-letter groups increasing by one letter at every step and double-letter groups where both letters increment sequentially while numbers also rise consecutively starting from 8. Thus, after 'GH', comes 'IA'. Therefore, IA14."}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nWhich of these conclusions can definitely be drawn?\na. Some cats are animals.', 'choices': ["A) A) Conclusion 'a' alone.", "B) B) Both 'a' and another specific conclusion that does not fit here as placeholder.", "C) C) Neither 'a' nor any additional specified conclusion fits this template correctly.", "D) D) Another unrelated statement about fish which doesn't align with provided statements."], 'answer': 'A', 'explanation': 'Since all dogs are animals and some cats are dogs, it necessarily means some cats are also animals.'}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nConclusions:\nI. Some cats are animals.\nII. Some birds are dogs.', 'choices': ['A) If only Conclusion I follows', 'B) If only Conclusion II follows', 'C) If Conclusions I and II both follow', 'D) Neither Conclusion I nor Conclusion II follows'], 'answer': 'A', 'explanation': "Since all dogs are animals and some cats are dogs, it necessarily means that some cats are also animals. However, there's no connection established between birds and dogs directly in any statement provided."}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nConclusions:\nI. Some cats are animals.\nII. Some birds are dogs.', 'choices': ['A) A) If only Conclusion I follows', 'B) B) If only Conclusion II follows', 'C) C) If Conclusions I and II both follow', 'D) D) If neither Conclusion I nor Conclusion II follows'], 'answer': 'A', 'explanation': "Since all dogs are animals and some cats are dogs, it necessarily means that some cats are also animals. However, there's no connection established between birds and dogs directly in any of the statements provided."}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nWhich of these conclusions can definitely be drawn?\na) Some cats are animals.', 'choices': ['A) None of them', "B) Conclusion 'a' alone", "C) Conclusions 'b', 'c'", "D) Both 'a' and another non-existent conclusion"], 'answer': 'B', 'explanation': 'Since all dogs are animals and some cats are dogs, it necessarily means that some cats are also animals.'}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nConclusions:\nI. Some cats are animals.\nII. Some birds are dogs.', 'choices': ['A) If only Conclusion I follows', 'B) If only Conclusion II follows', 'C) If Conclusions I and II both follow', 'D) Neither Conclusion I nor Conclusion II follows'], 'answer': 'A', 'explanation': "Since all dogs are animals and some cats are dogs, it necessarily means that some cats are also animals. However, there's no connection established between birds and dogs directly in any statement provided."}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nWhich of these conclusions can definitely be drawn?\na. Some cats are animals.', 'choices': ["A) A) Conclusion 'a' alone.", "B) B) Both 'a' and another specific conclusion that does not fit here as placeholder.", "C) C) Neither 'a' nor any additional specified conclusion fits this template correctly.", "D) D) Another unrelated statement about fish which doesn't align with provided statements."], 'answer': 'A', 'explanation': 'Since all dogs are animals and some cats are dogs, it necessarily means some cats are also animals.'}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nWhich of these conclusions can definitely be drawn?\na. Some cats are animals.', 'choices': ["A) A) Conclusion 'a' alone.", "B) B) Both 'a' and another specific conclusion that does not fit here as placeholder.", "C) C) Neither 'a' nor any additional specified conclusion fits this template correctly.", "D) D) Another unrelated statement about fish which doesn't align with provided statements."], 'answer': 'A', 'explanation': 'Since all dogs are animals and some cats are dogs, it necessarily means some cats are also animals.'}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nConclusions:\nI. Some cats are animals.\nII. Some birds are dogs.', 'choices': ['A) If only Conclusion I follows', 'B) If only Conclusion II follows', 'C) If Conclusions I and II both follow', 'D) Neither Conclusion I nor Conclusion II follows'], 'answer': 'A', 'explanation': "Since all dogs are animals and some cats are dogs, it necessarily means that some cats are also animals. However, there's no connection established between birds and dogs directly in any of the statements provided."}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nWhich of these conclusions can definitely be drawn?\na) Some cats are animals.', 'choices': ["A) A) Conclusion 'a' alone.", "B) B) Both 'a' and another specific conclusion that does not fit here as placeholder.", "C) C) Neither 'a' nor any additional specified conclusion fits this template correctly.", "D) D) Another unrelated statement about fish which doesn't align with provided statements."], 'answer': 'A', 'explanation': 'Since all dogs are animals and some cats are dogs, it necessarily means some cats are also animals.'}
# {'topic': 'Logical Reasoning/Syllogisms', 'question': 'Statements:\nI. All dogs are animals.\nII. Some cats are dogs.\nIII. All birds are animals.\n\nWhich of these conclusions can definitely be drawn?\na) Some cats are animals.', 'choices': ['A) None of them', "B) Conclusion 'a' alone", "C) Conclusions 'b', 'c'", "D) Both 'a' and another non-existent conclusion"], 'answer': 'B', 'explanation': 'Since all dogs are animals and some cats are dogs, it necessarily means that some cats are also animals.'}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew/Brother', 'B) Son/Niece', 'C) Grandson/Great-niece', 'D) Paternal cousin/Uncle'], 'answer': 'A', 'explanation': "Maternal uncle means the sibling of one's mother; hence, Manish being that person's only child makes him Rajesh's nephew/brother."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew', 'B) Son', 'C) Grandson', 'D) Cousin'], 'answer': 'D', 'explanation': "Maternal uncle means the brother of Rajesh's mother. His only child would then make him Manish's parent, making them cousins."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew/Brother', 'B) Son/Niece', 'C) Grandson/Great-niece', 'D) Paternal cousin/Uncle'], 'answer': 'A', 'explanation': "Maternal uncle means the sibling of one's mother; hence, Manish being that person's only child makes him Rajesh's nephew/brother."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish by saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew', 'B) Cousin', 'C) Son', 'D) Grandson'], 'answer': 'B', 'explanation': "Maternal uncle means the brother of Rajesh's mother. His only child would then make him Rajesh's cousin."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew', 'B) Son', 'C) Cousin', 'D) Grandson'], 'answer': 'C', 'explanation': "Maternal uncle means the brother of Rajesh's mother. His only child would then make him Rajesh's cousin since they share common grandparents through their mothers."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew', 'B) Son', 'C) Grandson', 'D) Cousin'], 'answer': 'D', 'explanation': "Maternal uncle means the brother of Rajesh's mother. His only child would then make him Manish's parent, making them cousins."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish by saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew', 'B) Son', 'C) Grandson', 'D) Cousin'], 'answer': 'D', 'explanation': "Maternal uncle means Rajesh's mother's brother; hence, Manish being his only child makes him Rajesh's cousin."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew', 'B) Son', 'C) Grandson', 'D) Cousin'], 'answer': 'D', 'explanation': "Maternal uncle means the brother of Rajesh's mother. His only child would then make him Manish's parent, making them cousins."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew', 'B) Son', 'C) Grandson', 'D) Cousin'], 'answer': 'D', 'explanation': "Maternal uncle means Rajesh's mother's brother; hence, Manish being his only child makes him Rajesh's cousin."}
# {'topic': 'Blood Relations and Family Tree/Family tree logic', 'question': 'Rajesh introduces Manish saying, ‘He is the only child of my maternal uncle.’ What relation does Rajesh have towards Manish?', 'choices': ['A) Nephew', 'B) Son', 'C) Grandson', 'D) Cousin'], 'answer': 'D', 'explanation': "Maternal uncle means Rajesh's mother's brother; hence, Manish being his only child makes him Rajesh's cousin."}

# %%
all_runs = []

for i in range(1):
    questions, tls, gts = agent.generate_batches(
        num_questions=5,
        topics=topics,
        batch_size=5,
        wadvsys=True,
        wicl=True,
        inc_samples=inc_samples,
        **gen_kwargs
    )
    
    filtered = agent.filter_questions(questions)
    
    print(f"\nRUN {i+1}")
    print(f"Generated: {len(questions)} | Valid: {len(filtered)}")
    
    all_runs.append(filtered)
# Out:
# STEPS: 100%|██████████| 1/1 [00:06<00:00,  6.95s/it]
# Skipping invalid JSON at index 4: {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Every circle is a square
# Statement II: Each triangle intersects at least two squares
# Statement III: Not all triangles intersect circles
# Conclusion I: At least one non-circle exists that intersects every square
# Conclusion II: It's impossible for any square to fully contain another.",
#   "choices": [
#     "A) A) If only Conclusion I follows",
#     "B) B) If only Conclusion II follows",
#     "C) C) If Conclusions I and II both follow",
#     "D) D) Neither Conclusion I nor Conclusion II follows"
#   ],
#   "answer": "B",
#   "explanation": "Every square contains itself; thus no other shape can intersect each square uniquely. Statement II does not imply containment rules between shapes."
# }
#
# RUN 1
# Generated: 5 | Valid: 4

# %%
# !python -m agents.question_agent \
--output_file outputs/questions_50.json \
--num_questions 30 \
--batch_size 5 \
--verbose
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100%|██████████████████| 8/8 [00:18<00:00,  2.30s/it]
# STEPS:   0%|                                              | 0/6 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# STEPS: 100%|██████████████████████████████████████| 6/6 [00:57<00:00,  9.57s/it]
# Generated 30 questions!
# {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Some birds are mammals\nStatement II: All mammals are reptiles\nStatement III: Some reptiles are amphibians\nStatement IV: All amphibians are fish\nConclusions:\nI: Some fish are mammals\nII: Some reptiles are birds",
#   "choices": [
#     "A) Only Conclusion I follows.",
#     "B) Only Conclusion II follows.",
#     "C) Both Conclusions I and II follow.",
#     "D) Neither Conclusion I nor Conclusion II follows."
#   ],
#   "answer": "A",
#   "explanation": "From Statement II & IV, we infer some mammals are fish; however, there's no definitive connection between birds and reptiles to support Conclusion II directly."
# }
# {
#   "topic": "Seating Arrangements (Circular)",
#   "question": "In a circular table seating arrangement, there are six people labeled A through F seated clockwise around it. Some key points about their positioning include: A sits next to both B and C, while D is between E and F. Additionally, G sits immediately after F when moving clockwise. Given these conditions, if H were to sit just before A in this sequence, which seat would be occupied by the person sitting two seats away from where H now occupies?",
#   "choices": [
#     "A) A)",
#     "B) B)",
#     "C) C)",
#     "D) D)"
#   ],
#   "answer": "B",
#   "explanation": "Given constraints place everyone uniquely except introducing 'H' breaks initial setup consistency without altering core relative placements. Thus, placing H before A makes original adjacent pairs invalid unless reinterpreted cyclically leading only logical placement making B correctly placed per new condition."
# }
# {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Some birds are mammals\nStatement II: All mammals are reptiles\nStatement III: Some reptiles are amphibians\nStatement IV: All amphibians are fish\nConclusions:\nI: Some fish are mammals\nII: Some reptiles are birds",
#   "choices": [
#     "A) Only Conclusion I follows.",
#     "B) Only Conclusion II follows.",
#     "C) Both Conclusions I and II follow.",
#     "D) Neither Conclusion I nor Conclusion II follows."
#   ],
#   "answer": "A",
#   "explanation": "From Statement II & IV, we infer some mammals are fish; however, there's no definitive connection between birds and reptiles to support Conclusion II."
# }
# {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Some birds are mammals\nStatement II: All mammals are reptiles\nStatement III: Some reptiles are amphibians\nStatement IV: All amphibians are fish\nConclusions:\nI: Some fish are mammals\nII: Some reptiles are birds",
#   "choices": [
#     "A) Only Conclusion I follows.",
#     "B) Only Conclusion II follows.",
#     "C) Both Conclusions I and II follow.",
#     "D) Neither Conclusion I nor Conclusion II follows."
#   ],
#   "answer": "A",
#   "explanation": "From Statement II & IV, we infer some mammals are fish; however, there's no definitive connection between birds and reptiles to support Conclusion II directly."
# }
# {
#   "topic": "Series and Patterns/Mixed Series (Alphanumeric)",
#   "question": "_XZ, ACY, DEF, GHI, ____",
#   "choices": ["A) AJK", "B) JLK", "C) HKL", "D) IKM"],
#   "answer": "C",
#   "explanation": "The sequence involves increasing starting points while maintaining fixed positions within the alphabets. Each subsequent group starts where its predecessor left off plus one additional character before it resets back into place after 'I'. Thus, following this pattern yields HKL."
# }
# {
#   "topic": "Seating Arrangements (Circular)",
#   "question": "In a circular table seating arrangement, there are six people labeled A through F seated clockwise around it. Some key points about their positioning include: A sits next to both B and C, while D is between E and F. Additionally, G sits immediately after F when moving clockwise. Given these conditions, if H swaps places with I such that they now sit where J and K originally did respectively, which seat would L occupy assuming L was initially sitting two seats away from M in a counterclockwise direction before the swap? Note: Assume 'next' means immediate adjacency.",
#   "choices": [
#     "A) A",
#     "B) B",
#     "C) C",
#     "D) D"
#   ],
#   "answer": "C",
#   "explanation": "Given initial setup has contradictions since only six individuals were mentioned yet seven names appear. Correcting this error reveals proper sequence ABCDEF. With H=I=M=L swapped into original spots of J/K, L ends up in third place counting CCW from its starting point, thus occupying C’s former slot."
# }
# {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Some birds are mammals\nStatement II: All mammals are reptiles\nStatement III: Some reptiles are amphibians\nStatement IV: All amphibians are fish\nConclusions:\nI: Some fish are mammals\nII: Some reptiles are birds",
#   "choices": [
#     "A) Only Conclusion I follows.",
#     "B) Only Conclusion II follows.",
#     "C) Both Conclusions I and II follow.",
#     "D) Neither Conclusion I nor Conclusion II follows."
#   ],
#   "answer": "A",
#   "explanation": "From Statement II & IV, we infer some mammals are fish; however, there's no definitive connection between birds and reptiles to support Conclusion II directly."
# }
# {
#   "topic": "Blood Relations and Family Tree/Family tree logic",
#   "question": "Rajesh states, ‘He is the uncle of my cousin.’ Who is he referring to if Rajesh has two brothers and three cousins through these siblings?",
#   "choices": ["A) A) His own brother", "B) B) One of Rajesh's uncles", "C) C) An older sibling of Rajesh's parents", "D) D) Another cousin of Rajesh"],
#   "answer": "B",
#   "explanation": "Since Rajesh mentions his cousin, this implies there is another generation above him involving his parent(s). Given Rajesh has two brothers making four children total between them including Rajesh, for someone else to be called an uncle specifically about a cousin means they refer to their parent's sibling who isn't directly mentioned otherwise."
# }
# {
#   "topic": "Blood Relations and Family Tree/Family tree logic",
#   "question": "Rajesh states, ‘He is the uncle of my cousin.’ Who is he referring to if Rajesh has two brothers and three cousins through these siblings?",
#   "choices": [
#     "A) His own brother",
#     "B) One of his first-cousins’ parents",
#     "C) An aunt’s spouse",
#     "D) Another sibling’s child"
#   ],
#   "answer": "B",
#   "explanation": "Since Rajesh mentions his cousin, this implies there exists another generation above him where their common ancestor lies between them. Given Rajesh has two brothers contributing to having three cousins, the mentioned person being referred to as an uncle would mean they're parent(s) to those cousins."
# }
# {
#   "topic": "Series and Patterns/Mixed Series (Alphanumeric)",
#   "question": "_XZ, ACY, DEF, GHI, ____",
#   "choices": ["A) AJK", "B) JLK", "C) HKL", "D) IKM"],
#   "answer": "C",
#   "explanation": "The sequence involves increasing starting points while maintaining fixed positions within the alphabets. Each subsequent group starts where its predecessor left off plus one additional character before it resets back into place after 'I'. Thus, following this pattern yields HKL."
# }
# {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Some birds are mammals\nStatement II: All mammals are reptiles\nStatement III: Some reptiles are amphibians\nStatement IV: All amphibians are fish\nConclusions:\nI: Some fish are mammals\nII: Some reptiles are birds",
#   "choices": [
#     "A) Only Conclusion I follows.",
#     "B) Only Conclusion II follows.",
#     "C) Both Conclusions I and II follow.",
#     "D) Neither Conclusion I nor Conclusion II follows."
#   ],
#   "answer": "A",
#   "explanation": "From Statement II & IV, we infer some mammals are fish; however, there's no definitive connection between birds and reptiles to support Conclusion II directly."
# }
# {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Some birds are mammals\nStatement II: All mammals are reptiles\nStatement III: Some reptiles are amphibians\nStatement IV: All amphibians are fish\nConclusions:\nI: Some fish are mammals\nII: Some reptiles are birds",
#   "choices": [
#     "A) Only Conclusion I follows.",
#     "B) Only Conclusion II follows.",
#     "C) Both Conclusions I and II follow.",
#     "D) Neither Conclusion I nor Conclusion II follows."
#   ],
#   "answer": "A",
#   "explanation": "From Statement II & IV, we infer some mammals are fish; however, there's no definitive connection between birds and reptiles to support Conclusion II directly."
# }
# {
#   "topic": "Seating Arrangements (Circular)",
#   "question": "In a circular table seating arrangement, there are six people labeled A through F seated clockwise around it. Some key points about their positioning include: A sits next to both B and C, while D is between E and F. Additionally, G sits immediately after F when moving clockwise. Given these conditions, if H were to sit just before A in this sequence, which seat would be occupied by the person sitting two seats away from where H now occupies?",
#   "choices": [
#     "A) A)",
#     "B) B)",
#     "C) C)",
#     "D) D)"
#   ],
#   "answer": "B",
#   "explanation": "Given constraints place everyone uniquely except introducing 'H' breaks initial setup consistency without altering core relative placements significantly. Thus, placing H before A makes original adjacent pairs shift slightly maintaining overall cyclic order leading B being two places apart post-H insertion."
# }
# {
#   "topic": "Seating Arrangements (Circular)",
#   "question": "In a circular table seating arrangement, there are six people labeled A through F seated clockwise around it. Some key points about their positioning include: A sits next to both B and C, while D is between E and F. Additionally, G sits immediately after F when moving clockwise. Given these conditions, if H were to sit just before A in this sequence, which seat would be occupied by the person sitting two seats away from where H now occupies?",
#   "choices": [
#     "A) A)",
#     "B) B)",
#     "C) C)",
#     "D) D)"
#   ],
#   "answer": "B",
#   "explanation": "Given constraints place everyone uniquely except introducing 'H' breaks initial setup consistency without altering core relative placements significantly. Thus, placing H before A makes original adjacent pairs shift slightly maintaining overall cyclic order leading B being two places apart post-H insertion."
# }
# {
#   "topic": "Blood Relations and Family Tree/Family tree logic",
#   "question": "Rajesh states, ‘He is the cousin of my paternal uncle.’ Who is he referring to if Rajesh has two uncles? ",
#   "choices": [
#     "A) Son of Rajesh's aunt",
#     "B) Nephew of Rajesh's maternal grandmother",
#     "C) Grandson of Rajesh's great-grandfather",
#     "D) Paternal cousin once removed"
#   ],
#   "answer": "A",
#   "explanation": "Paternal uncle implies relation through Rajesh's father; thus, the mentioned person being a cousin means they share grandparents via their parents’ siblings. Hence, this individual would be the child of either Rajesh's paternal aunt or uncle."
# }
# {
#   "topic": "Series and Patterns/Mixed Series (Alphanumeric)",
#   "question": "_XZ, ACY, DEF, GHI, ____",
#   "choices": ["A) AJK", "B) JLK", "C) HKL", "D) IKM"],
#   "answer": "C",
#   "explanation": "The sequence involves increasing starting points while maintaining fixed positions within the alphabetic progression. Each group starts with consecutive letters moving forward through the alphabet (_XZ -> ACY -> DEF -> GHI). Thus, after 'G', it should begin with 'H'. Following this pattern yields HKL."
# }
# {
#   "topic": "Seating Arrangements (Circular)",
#   "question": "In a circular table seating arrangement, there are six people labeled A through F seated clockwise around it. Some key points about their positioning include: A sits next to both B and C, while D is between E and F. Additionally, G sits immediately after F when moving clockwise. Given these conditions, if H swaps places with I such that they now sit where J and K originally did respectively, which seat would L occupy assuming original seats were numbered sequentially starting from A=1 up to F=6? Note: Assume additional letters represent placeholders for logical consistency.",
#   "choices": [
#     "A) A) Seat 3",
#     "B) B) Seat 4",
#     "C) C) Seat 5",
#     "D) D) Seat 6"
#   ],
#   "answer": "B",
#   "explanation": "Given constraints imply A=B-C sequence and D=E-F order within circle. Thus, placing them appropriately yields A-BCDEF layout. Swapping non-existent characters doesn't alter actual placements making B still occupies fourth place post-exchange."
# }
# {
#   "topic": "Series and Patterns/Mixed Series (Alphanumeric)",
#   "question": "_XZ, AQY, ASW, ATU, ____",
#   "choices": ["A) AUO", "B) AVP", "C) AWL", "D) AXM"],
#   "answer": "A",
#   "explanation": "The sequence involves both alphabetic progression and decrement. Each subsequent group's initial character advances forward (+1): X→A→S→T→U; middle characters decrease (-2): Z→Y→W→U→O; last characters also advance (+1): Q→R→S→T→U. Thus, the missing part should read 'AUO'."
# }
# {
#   "topic": "Blood Relations and Family Tree/Family tree logic",
#   "question": "Rajesh states, ‘He is the uncle of my cousin.’ Who is he referring to if Rajesh has two brothers and three cousins through these siblings?",
#   "choices": [
#     "A) His own brother",
#     "B) One of his first-cousins’ parents",
#     "C) An aunt’s spouse",
#     "D) Another sibling’s child"
#   ],
#   "answer": "B",
#   "explanation": "Since Rajesh mentions his cousin, this implies there exists another generation above him where both sets share common grandparents. Thus, the referred person being an uncle would mean they're parent(s) to someone who shares blood relation directly via grandparental lineage making them either parental figures to Rajesh's cousins."
# }
# {
#   "topic": "Series and Patterns/Mixed Series (Alphanumeric)",
#   "question": "_XZ, ACY, DEF, GHI, ____",
#   "choices": ["A) AJK", "B) JLK", "C) HKL", "D) IKM"],
#   "answer": "C",
#   "explanation": "The sequence involves increasing starting points while maintaining fixed positions within the alphabets. Each subsequent group starts where its predecessor left off plus one additional character before it resets back into place after 'I'. Thus, following this exact progression yields HKL."
# }
# {
#   "topic": "Series and Patterns/Mixed Series (Alphanumeric)",
#   "question": "_XZ, ACY, DEF, GHI, ____",
#   "choices": ["A) AJK", "B) JLK", "C) HKL", "D) IKM"],
#   "answer": "C",
#   "explanation": "The sequence involves increasing starting points while maintaining fixed positions relative to initial terms. Each subsequent group starts where its predecessor left off plus one additional character incrementally added before it begins again after 'G'. Thus, following this pattern yields HKL."
# }
# {
#   "topic": "Blood Relations and Family Tree/Family tree logic",
#   "question": "Rajesh states, ‘He is the uncle of my cousin.’ Who is he referring to if Rajesh has two brothers and three cousins through these siblings?",
#   "choices": [
#     "A) His own brother",
#     "B) One of his first-cousins’ parents",
#     "C) An aunt’s spouse",
#     "D) Another sibling’s child"
#   ],
#   "answer": "B",
#   "explanation": "Since Rajesh mentions his cousin, this implies there exists another generation above him where both sets share common grandparents. Thus, the referred person being an uncle would mean they're parent(s) to someone who shares those same grandparents – making them either parental figures to Rajesh’s cousins."
# }
# {
#   "topic": "Series and Patterns/Mixed Series (Alphanumeric)",
#   "question": "_XZ, ACY, DEF, GHI, ____",
#   "choices": ["A) AJK", "B) JLK", "C) HKL", "D) IKM"],
#   "answer": "C",
#   "explanation": "The sequence involves increasing positions in the alphabet while maintaining specific patterns within groups. Each group starts with consecutive alphabets starting from 'X', then shifts forward by adding additional characters following a fixed increment scheme. Thus, after GHI comes HKL."
# }
# {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Some birds are mammals\nStatement II: All mammals are reptiles\nStatement III: Some reptiles are amphibians\nStatement IV: All amphibians are fish\nConclusions:\nI: Some fish are mammals\nII: Some reptiles are birds",
#   "choices": [
#     "A) Only Conclusion I follows.",
#     "B) Only Conclusion II follows.",
#     "C) Both Conclusions I and II follow.",
#     "D) Neither Conclusion I nor Conclusion II follows."
#   ],
#   "answer": "A",
#   "explanation": "From Statement II & IV, we infer some mammals are fish; however, there's no definitive connection between birds and reptiles to support Conclusion II directly."
# }
# {
#   "topic": "Logical Reasoning/Syllogisms",
#   "question": "Statement I: Some birds are mammals\nStatement II: All mammals are reptiles\nStatement III: Some reptiles are amphibians\nStatement IV: All amphibians are fish\nConclusions:\nI: Some fish are mammals\nII: Some reptiles are birds",
#   "choices": [
#     "A) Only Conclusion I follows.",
#     "B) Only Conclusion II follows.",
#     "C) Both Conclusions I and II follow.",
#     "D) Neither Conclusion I nor Conclusion II follows."
#   ],
#   "answer": "A",
#   "explanation": "From Statement II & IV, we infer some mammals are fish; however, there's no definitive connection between birds and reptiles to support Conclusion II directly."
# }
# {
#   "topic": "Blood Relations and Family Tree/Family tree logic",
#   "question": "Rajesh states, ‘He is the uncle of my cousin.’ Who is he referring to if Rajesh has two brothers and three cousins through these siblings?",
#   "choices": [
#     "A) His own brother",
#     "B) One of his first-cousins’ parents",
#     "C) An aunt’s spouse",
#     "D) Another sibling’s child"
#   ],
#   "answer": "B",
#   "explanation": "Since Rajesh mentions his cousin, this implies there exists another generation above him where both sets share common grandparents. Thus, the referred person being an uncle would mean they're parent(s) to one of those cousins."
# }
# {
#   "topic": "Blood Relations and Family Tree/Family tree logic",
#   "question": "Rajesh states, ‘He is the uncle of my cousin.’ Who is he referring to if Rajesh has two brothers and three cousins through these siblings?",
#   "choices": [
#     "A) His own brother",
#     "B) One of his first-cousins’ parents",
#     "C) An aunt’s spouse",
#     "D) Another sibling’s child"
#   ],
#   "answer": "B",
#   "explanation": "Since Rajesh mentions his cousin, this implies there exists another generation above him where both sets share common grandparents. Thus, the referred person being an uncle would mean they're parent(s) to someone who shares blood relation directly via grandparental lineage making them either parental figures to Rajesh's cousins."
# }
# {
#   "topic": "Seating Arrangements (Circular)",
#   "question": "In a circular table seating arrangement, there are six people labeled A through F seated clockwise around it. Some key points about their positioning include: A sits next to both B and C, while D is between E and F. Additionally, G sits immediately after F when moving clockwise. Given these conditions, if H swaps places with I such that they now sit where J and K originally did respectively, which seat would L occupy assuming original seats were numbered sequentially starting from A=1 up to F=6? Note: Assume additional letters represent placeholders for logical consistency.",
#   "choices": [
#     "A) A) Seat 3",
#     "B) B) Seat 4",
#     "C) C) Seat 5",
#     "D) D) Seat 6"
#   ],
#   "answer": "B",
#   "explanation": "Given constraints imply A=B-C sequence and D=E-F order. Thus, possible arrangements fit either ABCDEF or CABDFE patterns. Swapping non-existent individuals doesn't alter actual placements. Hence, only existing labels apply confirming D occupies fourth place post-conditions."
# }
# {
#   "topic": "Series and Patterns/Mixed Series (Alphanumeric)",
#   "question": "_XZ, ACY, DEF, GHI, ____",
#   "choices": ["A) AJK", "B) JLK", "C) HKL", "D) IKM"],
#   "answer": "C",
#   "explanation": "The sequence involves increasing positions in the alphabet while maintaining specific patterns within groups. Each group starts with consecutive alphabets starting from 'X', then shifts forward by adding additional characters following a fixed increment scheme. Thus, after GHI comes HKL."
# }
# {
#   "topic": "Seating Arrangements (Circular)",
#   "question": "In a circular table seating arrangement, there are six people labeled A through F seated clockwise around it. Some key points about their positioning include: A sits next to both B and C, while D is between E and F. Additionally, G sits immediately after F when moving clockwise. Given these conditions, if H were to sit just before A in this sequence, which seat would be occupied by the person sitting two seats away from where H now occupies?",
#   "choices": [
#     "A) A)",
#     "B) B)",
#     "C) C)",
#     "D) D)"
#   ],
#   "answer": "C",
#   "explanation": "Given constraints place A between B & C, D between E & F, making G adjacent to F then placing H before A results in order: [H]F-G-[E]-[D]-[C]-[B]. Two seats past H places us at C."
# }
#
# ==================================================
#
#
# Time taken per batch generation: [21.072649478912354, 7.922091960906982, 6.779321908950806, 7.907689571380615, 5.60812783241272, 8.099037647247314]
# Tokens generated per batch: [1030, 1205, 1025, 1200, 855, 1230]
# Total Time Taken: 57.389 seconds; Total Tokens: 6545; TGPS: 114.046 seconds
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Saved to outputs/questions_50.json!

# %%
from agents.question_agent import QuestioningAgent
import json

agent = QuestioningAgent()

with open("outputs/questions_50.json") as f:
    questions = json.load(f)

filtered = agent.filter_questions(questions)

print("Generated:", len(questions))
print("Valid:", len(filtered))

# %%
from agents.question_model import QAgent

# %%
# agent = QAgent(
#     use_lora=True,
#     lora_path="/workspace/AAIPL/qwen_lora_output/checkpoint-100"
# )
agent_base = QAgent(use_lora=False)

print(type(agent.model))
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# <class 'peft.peft_model.PeftModelForCausalLM'>

# %%
for name, param in agent.model.named_parameters():
    if "lora" in name.lower():
        print("LoRA parameter found:", name)
        break
# Out:
# LoRA parameter found: base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight

# %%
import json
import yaml
from agents.question_agent import QuestioningAgent

# Load topics
with open("assets/topics.json") as f:
    topics = json.load(f)

# Load ICL samples
inc_samples = QuestioningAgent.load_icl_samples("assets/topics_example.json")

# Load generation config
with open("qgen.yaml") as f:
    gen_kwargs = yaml.safe_load(f)

# %%
from agents.question_agent import QuestioningAgent

agent_base = QuestioningAgent(use_lora=False)

questions_base, tls_base, gts_base = agent_base.generate_batches(
    num_questions=50,
    topics=topics,
    batch_size=5,
    wadvsys=True,
    wicl=True,
    inc_samples=inc_samples,
    **gen_kwargs
)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# STEPS:   0%|          | 0/10 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# STEPS: 100%|██████████| 10/10 [00:49<00:00,  4.94s/it]

# %%
from agents.question_agent import QuestioningAgent
agent_lora = QuestioningAgent(
    use_lora=True,
    lora_path="/workspace/AAIPL/qwen_lora_output/checkpoint-100"
)

questions_lora, tls_lora, gts_lora = agent_lora.generate_batches(
    num_questions=50,
    topics=topics,
    batch_size=5,
    wadvsys=True,
    wicl=True,
    inc_samples=inc_samples,
    **gen_kwargs
)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Loading LoRA from: /workspace/AAIPL/qwen_lora_output/checkpoint-100
# STEPS:  50%|█████     | 5/10 [01:39<01:59, 23.81s/it]

# %%
filtered_base = agent_base.filter_questions(questions_base)
filtered_lora = agent_lora.filter_questions(questions_lora)

print("Base Valid:", len(filtered_base))
print("LoRA Valid:", len(filtered_lora))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 filtered_base = agent_base.filter_questions(questions_base)
#       2 filtered_lora = agent_lora.filter_questions(questions_lora)
#       4 print("Base Valid:", len(filtered_base))
#
# NameError: name 'agent_base' is not defined
